# %%
from herbie import Herbie
from toolbox import EasyMap, pc
from x import 

import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
h = Herbie('2024-02-18')
# Out:
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2024-Feb-18 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws

# %%
ds = h.xarray(r":03TOT")
ds
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 ds = h.xarray(r":03TOT")
#       2 ds
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/skagit-met/lib/python3.9/site-packages/herbie/core.py:1121, in Herbie.xarray(self, search, searchString, backend_kwargs, remove_grib, **download_kwargs)
#    1117 backend_kwargs.setdefault("errors", "raise")
#    1119 # Use cfgrib.open_datasets, just in case there are multiple "hypercubes"
#    1120 # for what we requested.
# -> 1121 Hxr = cfgrib.open_datasets(
#    1122     local_file,
#    1123     backend_kwargs=backend_kwargs,
#    1124 )
#    1126 # Get CF grid projection information with pygrib and pyproj because
#    1127 # this is something cfgrib doesn't do (https://github.com/ecmwf/cfgrib/issues/251)
#    1128 # NOTE: Assumes the projection is the same for all variables
#    1129 with pygrib.open(str(local_file)) as grb:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/skagit-met/lib/python3.9/site-packages/cfgrib/xarray_store.py:105, in open_datasets(path, backend_kwargs, **kwargs)
#     103 backend_kwargs = backend_kwargs.copy()
#     104 backend_kwargs["squeeze"] = False
# --> 105 datasets = open_variable_datasets(path, backend_kwargs=backend_kwargs, **kwargs)
#     107 type_of_level_datasets = {}  # type: T.Dict[str, T.List[xr.Dataset]]
#     108 for ds in datasets:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/skagit-met/lib/python3.9/site-packages/cfgrib/xarray_store.py:87, in open_variable_datasets(path, backend_kwargs, **kwargs)
#      85 errors = backend_kwargs.get("errors", "warn")
#      86 stream = messages.FileStream(path, errors=errors)
# ---> 87 index = open_fileindex(stream, computed_keys=cfmessage.COMPUTED_KEYS, **fileindex_kwargs)
#      88 datasets = []  # type: T.List[xr.Dataset]
#      89 for param_id in sorted(index["paramId"]):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/skagit-met/lib/python3.9/site-packages/cfgrib/dataset.py:778, in open_fileindex(stream, indexpath, index_keys, filter_by_keys, computed_keys)
#     770 def open_fileindex(
#     771     stream: messages.FileStream,
#     772     indexpath: str = messages.DEFAULT_INDEXPATH,
#    (...)
#     775     computed_keys: messages.ComputedKeysType = cfmessage.COMPUTED_KEYS,
#     776 ) -> messages.FileIndex:
#     777     index_keys = sorted(set(index_keys) | set(filter_by_keys))
# --> 778     index = messages.FileIndex.from_indexpath_or_filestream(
#     779         stream, index_keys, indexpath=indexpath, computed_keys=computed_keys
#     780     )
#     781     return index.subindex(filter_by_keys)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/skagit-met/lib/python3.9/site-packages/cfgrib/messages.py:529, in FileIndex.from_indexpath_or_filestream(cls, filestream, index_keys, indexpath, computed_keys, log)
#     521 @classmethod
#     522 def from_indexpath_or_filestream(
#     523     cls, filestream, index_keys, indexpath=DEFAULT_INDEXPATH, computed_keys={}, log=LOG
#    (...)
#     526
#     527     # Reading and writing the index can be explicitly suppressed by passing indexpath==''.
#     528     if not indexpath:
# --> 529         return cls.from_fieldset(filestream, index_keys, computed_keys)
#     531     hash = hashlib.md5(repr(index_keys).encode("utf-8")).hexdigest()
#     532     indexpath = indexpath.format(path=filestream.path, hash=hash, short_hash=hash[:5])
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/skagit-met/lib/python3.9/site-packages/cfgrib/messages.py:378, in FieldsetIndex.from_fieldset(cls, fieldset, index_keys, computed_keys)
#     376 else:
#     377     iteritems = enumerate(fieldset)
# --> 378 return cls.from_fieldset_and_iteritems(fieldset, iteritems, index_keys, computed_keys)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/skagit-met/lib/python3.9/site-packages/cfgrib/messages.py:391, in FieldsetIndex.from_fieldset_and_iteritems(cls, fieldset, iteritems, index_keys, computed_keys)
#     389 index_keys = list(index_keys)
#     390 header_values_cache = {}  # type: T.Dict[T.Tuple[T.Any, type], T.Any]
# --> 391 for field_id, raw_field in iteritems:
#     392     field = ComputedKeysAdapter(raw_field, computed_keys)
#     393     header_values = []
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/skagit-met/lib/python3.9/site-packages/cfgrib/messages.py:291, in FileStreamItems.__iter__(self)
#     289 old_offset = -1
#     290 count = 0
# --> 291 for message in self.itervalues():
#     292     offset = message.message_get("offset", int)
#     293     if offset == old_offset:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/skagit-met/lib/python3.9/site-packages/cfgrib/messages.py:267, in FileStreamItems.itervalues(self)
#     265 def itervalues(self) -> T.Iterator[Message]:
#     266     errors = self.filestream.errors
# --> 267     with open(self.filestream.path, "rb") as file:
#     268         # enable MULTI-FIELD support on sequential reads (like when building the index)
#     269         with multi_enabled(file):
#     270             valid_message_found = False
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/jesse/data/hrrr/20240218/subset_4defb1fe__hrrr.t00z.wrfsfcf00.grib2'

# %%
# ax = EasyMap("110m", crs=ds.herbie.crs, figsize=[10, 8]).STATES().ax

# p = ax.pcolormesh(
#     ds.longitude,
#     ds.latitude,
#     ds.sde,
#     transform=pc
# )
# plt.colorbar(
#     p,
#     ax=ax,
#     orientation="horizontal",
#     pad=0.01,
#     shrink=0.8
# )

# ax.set_title(
#     f"{ds.model.upper()}: {h.product_description}\nValid: {ds.valid_time.dt.strftime('%H:%M UTC %d %b %Y').item()}",
#     loc="left",
# )
# ax.set_title(ds.sde.GRIB_name, loc="right")

ds.herbie.plot()
# Out:
# cfgrib variable: csnow
# GRIB_cfName unknown
# GRIB_cfVarName csnow
# GRIB_name Categorical snow
# GRIB_units (Code table 4.222)
# GRIB_typeOfLevel surface
# /opt/homebrew/Caskroom/miniforge/base/envs/skagit-met/lib/python3.9/site-packages/herbie/accessors.py:730: UserWarning: More than one time coordinate present for variable  "csnow".
#   ds = ds.metpy.assign_y_x()
# <GeoAxes: title={'left': 'Run: 00:00 UTC 18 Feb 2024 F00', 'center': 'HRRR  surface\n', 'right': 'Valid: 00:00 UTC 18 Feb 2024'}>
