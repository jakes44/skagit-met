# %%
from pyPRISMClimate import get_prism_monthlys, get_prism_monthly_single, get_prism_dailys, get_prism_daily_single, get_prism_normals
from pyPRISMClimate.utils import prism_iterator
import rioxarray as rxr
import xarray as xr

# %%
# Get daily maximum temperature for Jan. 1, 2017 to Feb. 20, 2017
get_prism_dailys('tmax',min_date='2017-01-01', max_date='2017-02-01', dest_path='./data/')

# %%
iterator = prism_iterator('./data')

# %%
datasets = [rxr.open_rasterio(f['full_path']) for f in iterator]

# %%
d = datasets[0]

# %%
d
# Out:
# <xarray.DataArray (band: 1, y: 621, x: 1405)> Size: 3MB
# [872505 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 11kB -125.0 -125.0 -124.9 ... -66.58 -66.54 -66.5
#   * y            (y) float64 5kB 49.92 49.88 49.83 49.79 ... 24.17 24.12 24.08
#     spatial_ref  int64 8B 0
# Attributes:
#     STATISTICS_MAXIMUM:  29.666000366211
#     STATISTICS_MEAN:     8.8865924105447
#     STATISTICS_MINIMUM:  -13.09700012207
#     STATISTICS_STDDEV:   8.6601624380055
#     _FillValue:          -9999.0
#     scale_factor:        1.0
#     add_offset:          0.0
